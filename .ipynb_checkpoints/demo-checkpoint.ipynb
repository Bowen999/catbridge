# %%
#导入 CATBridge
import catbridge as cat
# Out:
#
#
#  ██████╗ █████╗ ████████╗    ██████╗ ██████╗ ██╗██████╗  ██████╗ ███████╗
# ██╔════╝██╔══██╗╚══██╔══╝    ██╔══██╗██╔══██╗██║██╔══██╗██╔════╝ ██╔════╝
# ██║     ███████║   ██║       ██████╔╝██████╔╝██║██║  ██║██║  ███╗█████╗
# ██║     ██╔══██║   ██║       ██╔══██╗██╔══██╗██║██║  ██║██║   ██║██╔══╝
# ╚██████╗██║  ██║   ██║       ██████╔╝██║  ██║██║██████╔╝╚██████╔╝███████╗
#  ╚═════╝╚═╝  ╚═╝   ╚═╝       ╚═════╝ ╚═╝  ╚═╝╚═╝╚═════╝  ╚═════╝ ╚══════╝
#
#
#                                    ___
#                       |\---/|  / )|Guo|
#           ------------;     |-/ / |Lab|
#                       )     (' /  `---'
#           ===========(       ,'==========
#           ||  _      |      |
#           || ( (    /       ;
#           ||  \ `._/       /
#           ||   `._        /|
#           ||      |\    _/||
#         __||_____.' )  |__||____________
#          ________\  |  |_________________
#                   \ \  `-.
#                    `-`---'
#
#
#
#
# CAT Bridge is a Python-based, cross-platform tool designed for integrated analysis of transcriptomes and metabolites. It is adept at processing time series data, aiding in the discovery of genes contributing to specific metabolite synthesis.
#
# For more information on our other research outputs, welcome to visit the Guo Lab's website at: http://www.guo-lab.site.
#
# For any queries about this software, feel free to contact us at by8@ualberta.ca.

# %% [markdown]
# # 1.数据读取与预览

# %%
#转录组数据（TPM）
gene = cat.read_upload('gene.tsv')
gene
# Out:
#                        00D_1       00D_2       00D_3      07D_1      07D_2
# Name
# Cc72_00056795-RA    0.000000    0.000000    0.000000   0.000000   0.000000  \
# Cc72_00056752-RA    0.137798    0.316671    0.728767   0.417197   1.129790
# Cc72_00056749-RA    0.000000    0.000000    0.000000   0.000000   0.000000
# Cc72_00056747-RA    0.000000    0.000000    0.000000   0.000000   0.000000
# Cc72_00056748-RA    9.958670    6.138120    5.773460   4.404880   2.511830
# ...                      ...         ...         ...        ...        ...
# Cc72_00056725-RA    0.000000    0.047850    0.000000   0.000000   0.103972
# Cc72_00056720-RA  389.434000  177.032000  298.304000  91.136400  87.400400
# Cc72_00056719-RA    0.000000    0.000000    0.000000   0.000000   0.000000
# Cc72_00056724-RA    0.000000    0.000000    0.000000   0.000000   0.000000
# Cc72_00056722-RA    0.000000    0.000000    0.000000   0.000000   0.000000
#
#                        07D_3      16D_1     16D_2     16D_3     30D_1  ...
# Name                                                                   ...
# Cc72_00056795-RA    0.000000   0.000000   0.00000   0.00000   0.00000  ...  \
# Cc72_00056752-RA    0.580265   0.822207   1.39466   2.02979   1.57553  ...
# Cc72_00056749-RA    0.000000   0.000000   0.00000   0.00000   0.00000  ...
# Cc72_00056747-RA    0.000000   0.000000   0.00000   0.00000   0.00000  ...
# Cc72_00056748-RA    3.364190   0.656713   0.00000   0.67818   3.51545  ...
# ...                      ...        ...       ...       ...       ...  ...
# Cc72_00056725-RA    0.000000   0.046317   0.00000   0.00000   0.00000  ...
# Cc72_00056720-RA  347.349000  52.240300  89.07430  42.55410  80.84700  ...
# Cc72_00056719-RA    0.000000   0.000000   0.00000   0.00000   0.00000  ...
# Cc72_00056724-RA    0.000000   0.000000   0.00000   0.00000   0.00000  ...
# Cc72_00056722-RA    0.000000   0.000000   0.00000   0.00000   0.00000  ...
#
#                      30D_3      50D_1       50D_2      50D_3       55D_1
# Name
# Cc72_00056795-RA   0.00000   0.000000    0.000000   0.000000    0.000000  \
# Cc72_00056752-RA   1.85280   2.445510    1.931790   5.429260    0.282856
# Cc72_00056749-RA   0.00000   0.000000    0.623423   0.000000    0.000000
# Cc72_00056747-RA   0.00000   0.000000    0.000000   0.000000    0.000000
# Cc72_00056748-RA   3.07949   0.640350    3.221760   5.903450    1.528760
# ...                    ...        ...         ...        ...         ...
# Cc72_00056725-RA   0.00000   0.059125    0.000000   0.056314    0.000000
# Cc72_00056720-RA  71.95430  61.253100  102.950000  94.298600  172.745000
# Cc72_00056719-RA   0.00000   0.000000    0.000000   0.000000    0.000000
# Cc72_00056724-RA   0.00000   0.000000    0.000000   0.000000    0.000000
# Cc72_00056722-RA   0.00000   0.000000    0.000000   0.000000    0.000000
#
#                       55D_2      55D_3      60D_1      60D_2      60D_3
# Name
# Cc72_00056795-RA   0.000000   0.000000   0.000000   0.000000   0.000000
# Cc72_00056752-RA   0.371977   0.234484   0.225051   0.069294   0.107668
# Cc72_00056749-RA   0.000000   0.000000   0.540083   0.000000   0.000000
# Cc72_00056747-RA   0.000000   0.000000   0.000000   0.000000   0.000000
# Cc72_00056748-RA   1.928270   1.591710   0.911864   1.307940   0.823497
# ...                     ...        ...        ...        ...        ...
# Cc72_00056725-RA   0.000000   0.204317   0.000000   0.000000   0.000000
# Cc72_00056720-RA  53.027400  41.620600  63.766000  53.298500  62.351500
# Cc72_00056719-RA   0.000000   0.000000   0.000000   0.000000   0.000000
# Cc72_00056724-RA   0.000000   0.000000   0.000000   0.000000   0.000000
# Cc72_00056722-RA   0.000000   0.000000   0.000000   0.000000   0.000000
#
# [56797 rows x 21 columns]

# %%
#代谢组数据
metabo = cat.read_upload('metabo.tsv')
metabo
# Out:
#                                                            00D_1
# Name
# (+/-)-C75                                           2.328435e+06  \
# (-)-Caryophyllene oxide                             1.643851e+08
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  1.564848e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  1.169464e+07
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.678938e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  1.396740e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.561690e+08
# α,α-Trehalose                                       1.123622e+07
# β-D-Glucopyranuronic acid                           4.112623e+07
# δ-Ribono-1,4-lactone                                2.759393e+08
#
#                                                            00D_2
# Name
# (+/-)-C75                                           2.698359e+06  \
# (-)-Caryophyllene oxide                             1.509719e+08
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  1.695966e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  1.178717e+07
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.447137e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  8.212702e+05
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.701510e+08
# α,α-Trehalose                                       1.047747e+07
# β-D-Glucopyranuronic acid                           4.434874e+07
# δ-Ribono-1,4-lactone                                2.747910e+08
#
#                                                            00D_3
# Name
# (+/-)-C75                                           1.423818e+06  \
# (-)-Caryophyllene oxide                             1.538677e+08
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  1.914702e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  1.051847e+07
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.580314e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  8.583202e+05
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.788883e+08
# α,α-Trehalose                                       1.100953e+07
# β-D-Glucopyranuronic acid                           4.557195e+07
# δ-Ribono-1,4-lactone                                2.599410e+08
#
#                                                            07D_1
# Name
# (+/-)-C75                                           5.117225e+05  \
# (-)-Caryophyllene oxide                             8.403575e+07
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  7.444341e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  2.333734e+07
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.332373e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  1.396129e+05
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  2.998157e+07
# α,α-Trehalose                                       1.248077e+08
# β-D-Glucopyranuronic acid                           7.877319e+07
# δ-Ribono-1,4-lactone                                3.844331e+08
#
#                                                            07D_2
# Name
# (+/-)-C75                                           1.209506e+06  \
# (-)-Caryophyllene oxide                             7.261335e+07
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  6.484402e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  2.729838e+07
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.592984e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  1.438539e+05
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  3.566032e+07
# α,α-Trehalose                                       1.395024e+08
# β-D-Glucopyranuronic acid                           8.080489e+07
# δ-Ribono-1,4-lactone                                4.265292e+08
#
#                                                            07D_3
# Name
# (+/-)-C75                                           1.335991e+06  \
# (-)-Caryophyllene oxide                             8.665233e+07
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  7.346802e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  2.501318e+07
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.052962e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  1.269555e+05
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  3.884425e+07
# α,α-Trehalose                                       1.223033e+08
# β-D-Glucopyranuronic acid                           6.882041e+07
# δ-Ribono-1,4-lactone                                4.087823e+08
#
#                                                            16D_1
# Name
# (+/-)-C75                                           1.164401e+06  \
# (-)-Caryophyllene oxide                             1.946265e+07
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  6.813409e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  6.965506e+06
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.899303e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  1.401442e+05
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.533503e+07
# α,α-Trehalose                                       3.133516e+08
# β-D-Glucopyranuronic acid                           1.603987e+08
# δ-Ribono-1,4-lactone                                1.846482e+08
#
#                                                            16D_2
# Name
# (+/-)-C75                                           1.403493e+06  \
# (-)-Caryophyllene oxide                             2.574257e+07
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  6.655326e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  9.073465e+06
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.215258e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  1.380108e+05
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.781640e+07
# α,α-Trehalose                                       3.470801e+08
# β-D-Glucopyranuronic acid                           1.451636e+08
# δ-Ribono-1,4-lactone                                2.209860e+08
#
#                                                            16D_3
# Name
# (+/-)-C75                                           1.965722e+06  \
# (-)-Caryophyllene oxide                             1.536607e+07
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  9.426496e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  5.702783e+06
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.455055e+07
# ...                                                          ...
# p-Coumaryl alcohol                                  1.550036e+05
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  2.719956e+07
# α,α-Trehalose                                       2.529097e+08
# β-D-Glucopyranuronic acid                           1.340063e+08
# δ-Ribono-1,4-lactone                                1.221445e+08
#
#                                                            30D_1  ...
# Name                                                              ...
# (+/-)-C75                                           4.655820e+06  ...  \
# (-)-Caryophyllene oxide                             7.094577e+06  ...
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  5.120517e+07  ...
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  4.724727e+05  ...
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  4.224064e+06  ...
# ...                                                          ...  ...
# p-Coumaryl alcohol                                  2.023163e+06  ...
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.205777e+07  ...
# α,α-Trehalose                                       3.410956e+08  ...
# β-D-Glucopyranuronic acid                           7.689330e+07  ...
# δ-Ribono-1,4-lactone                                8.804313e+07  ...
#
#                                                            30D_3
# Name
# (+/-)-C75                                           4.178101e+06  \
# (-)-Caryophyllene oxide                             8.583746e+06
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  5.991464e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  4.861932e+05
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  4.659618e+06
# ...                                                          ...
# p-Coumaryl alcohol                                  2.510988e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.617575e+07
# α,α-Trehalose                                       5.824696e+08
# β-D-Glucopyranuronic acid                           6.752700e+07
# δ-Ribono-1,4-lactone                                7.015185e+07
#
#                                                            50D_1
# Name
# (+/-)-C75                                           5.215819e+06  \
# (-)-Caryophyllene oxide                             2.720165e+06
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  1.331855e+06
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  3.947515e+05
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  3.274229e+06
# ...                                                          ...
# p-Coumaryl alcohol                                  2.478152e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  4.532575e+06
# α,α-Trehalose                                       1.853917e+09
# β-D-Glucopyranuronic acid                           5.452015e+07
# δ-Ribono-1,4-lactone                                4.578022e+07
#
#                                                            50D_2
# Name
# (+/-)-C75                                           4.490974e+06  \
# (-)-Caryophyllene oxide                             4.126383e+06
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  3.604714e+06
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  1.249524e+06
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  4.265600e+06
# ...                                                          ...
# p-Coumaryl alcohol                                  5.153305e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.626435e+07
# α,α-Trehalose                                       1.641911e+09
# β-D-Glucopyranuronic acid                           6.004896e+07
# δ-Ribono-1,4-lactone                                5.449962e+07
#
#                                                            50D_3
# Name
# (+/-)-C75                                           7.416386e+06  \
# (-)-Caryophyllene oxide                             6.039011e+06
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  1.474834e+06
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  3.999475e+05
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  5.015977e+06
# ...                                                          ...
# p-Coumaryl alcohol                                  2.997565e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.748965e+07
# α,α-Trehalose                                       1.653810e+09
# β-D-Glucopyranuronic acid                           6.673379e+07
# δ-Ribono-1,4-lactone                                6.060312e+07
#
#                                                            55D_1
# Name
# (+/-)-C75                                           4.352038e+06  \
# (-)-Caryophyllene oxide                             8.134036e+06
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  1.286745e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  3.920049e+05
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  3.602735e+06
# ...                                                          ...
# p-Coumaryl alcohol                                  1.833329e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  6.870734e+06
# α,α-Trehalose                                       9.981471e+08
# β-D-Glucopyranuronic acid                           8.756464e+07
# δ-Ribono-1,4-lactone                                6.418872e+07
#
#                                                            55D_2
# Name
# (+/-)-C75                                           4.774761e+06  \
# (-)-Caryophyllene oxide                             2.868262e+06
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  1.136265e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  6.158650e+05
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  3.996653e+06
# ...                                                          ...
# p-Coumaryl alcohol                                  4.006805e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  2.873117e+07
# α,α-Trehalose                                       8.738896e+08
# β-D-Glucopyranuronic acid                           6.742380e+07
# δ-Ribono-1,4-lactone                                5.766829e+07
#
#                                                            55D_3
# Name
# (+/-)-C75                                           6.053115e+06  \
# (-)-Caryophyllene oxide                             1.879457e+06
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  3.737829e+06
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  3.932121e+05
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  1.951436e+06
# ...                                                          ...
# p-Coumaryl alcohol                                  2.116769e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.042562e+07
# α,α-Trehalose                                       8.378855e+08
# β-D-Glucopyranuronic acid                           8.483156e+07
# δ-Ribono-1,4-lactone                                5.838523e+07
#
#                                                            60D_1
# Name
# (+/-)-C75                                           2.555613e+06  \
# (-)-Caryophyllene oxide                             1.626355e+07
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  1.446105e+07
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  4.464792e+05
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  2.972090e+06
# ...                                                          ...
# p-Coumaryl alcohol                                  2.157100e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  6.634874e+06
# α,α-Trehalose                                       9.951859e+07
# β-D-Glucopyranuronic acid                           9.182750e+07
# δ-Ribono-1,4-lactone                                7.897890e+07
#
#                                                            60D_2         60D_3
# Name
# (+/-)-C75                                           3.942995e+06  2.602865e+06
# (-)-Caryophyllene oxide                             1.992055e+07  1.783439e+07
# (1R,2S,3R,4R)-3-[(Cyclopentylmethyl)amino]-4-ph...  2.549558e+06  7.496871e+05
# (1R,4aS,5R,8aS)-5-(5-hydroxy-3-methylpentyl)-1,...  5.161708e+05  4.624713e+05
# (1S,3R,4R,5R)-1,3,4-trihydroxy-5-{[(2E)-3-(4-hy...  4.487863e+06  1.387103e+07
# ...                                                          ...           ...
# p-Coumaryl alcohol                                  1.198581e+06  1.158435e+06
# {(1R,2R)-2-[(2Z)-5-(Hexopyranosyloxy)-2-penten-...  1.703261e+07  7.667502e+06
# α,α-Trehalose                                       4.972597e+07  7.703706e+07
# β-D-Glucopyranuronic acid                           1.135584e+08  8.887386e+07
# δ-Ribono-1,4-lactone                                6.602121e+07  6.867678e+07
#
# [775 rows x 21 columns]

# %%
nor_gene = cat.normalize(gene, 'log10')
cat.plot_heatmap(nor_gene, palette='vlag', figsize=(10, 8), row_threshold=50, save_path=None)

# %%
nor_metabo = cat.normalize(metabo, 'log10')
cat.plot_heatmap(nor_metabo, palette='vlag', figsize=(10, 8), row_threshold=50, save_path=None)

# %% [markdown]
# # 2.计算

# %%
#使用第三次重复作为测试数据
gene = gene.filter(regex='_3')
metabo = metabo.filter(regex='_3')

# %%
#选取Capsaicin作为目标代谢物
target = cat.read_target('Capsaicin', metabo)
cat.plot_line(target, 'Capsaicin')

# %% [markdown]
# ### 分别计算granger causality，Spearman's rank correlation coefficient，Pearson's rank correlation coefficient

# %%
granger = cat.compute_granger(gene, target, maxlag=1)
spearman = cat.compute_spearman(gene, target)
pearson = cat.compute_pearson(gene, target)
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Applications/anaconda3/lib/python3.9/site-packages/scipy/stats/_stats_py.py:4916: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# /Applications/anaconda3/lib/python3.9/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %% [markdown]
# ### 目标代谢物的峰值时间点与下一时间点的Fold Change，由DESeq2计算。由于DESeq2基于R，目前还未接入到Pipeline里，所以直接读取计算结果

# %%
fc = cat.read_upload('/Users/bowen/Desktop/CatBridge1.1/result/fc.csv')

# %% [markdown]
# ### 基因功能注释可以通过同源注释工具获得，如eggnog-mapper（此demo所使用），BLAST等

# %%
annotation = cat.read_upload('/Users/bowen/Desktop/CatBridge1.1/result/gene_annotation.tsv')
data = cat.merge_dataframes([granger, fc, pearson, spearman, annotation])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 annotation = cat.read_upload('/Users/bowen/Desktop/CatBridge1.1/result/gene_annotation.tsv')
#       2 data = cat.merge_dataframes([granger, fc, pearson, spearman, annotation])
#
# File ~/Documents/GitHub/catbridge/catbridge.py:29, in read_upload(file_name)
#      27 #if the last 3 letters of the file name is tsv, we use csv module to read it
#      28 elif file_name[-3:] == 'tsv':
# ---> 29     df = pd.read_csv(file_name, sep='\t', index_col=0)
#      30 return df
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/bowen/Desktop/CatBridge1.1/result/gene_annotation.tsv'

# %%
data = cat.merge_dataframes([granger, fc, pearson, spearman, annotation])

# %% [markdown]
# ### 对log2FoldChange进行归一化，使得取值范围映射到 0-1

# %%
data = cat.scale_column(data, 'log2FoldChange')
data = data.fillna(0)

# %% [markdown]
# # 3.打分&排序

# %% [markdown]
# ### Score = Fold Change(归一化) + Granger + 注释分（根据关键词打分）

# %%
keywords_scores = {'ase': 0.2, 'enzyme': 0.2, 'synthase': 0.2, '0': 0.1}
data = cat.compute_score(data, 'log2FoldChange', 'Granger', 'Description', keywords_scores)

# %%
data

# %% [markdown]
# ### 对基因根据数据序列进行聚类，同上，由于计算所需要使用的Mfuzz基于R，所以直接导入计算结果

# %%
cluster = cat.read_upload('/Users/bowen/Desktop/CatBridge1.1/result/mfuzz_clusters.txt')

# %% [markdown]
# ### 查看结果是否符合预期（通过BLAST）

# %%
blast = cat.read_upload('/Users/bowen/Desktop/CatBridge1.1/result/blast.txt')
top_hits = cat.merge_dataframes([blast, cluster, data])
top_hits = top_hits.drop(columns=['Granger','log2FoldChange', 'Spearman', 'Pearson'])

# %%
top_hits.head(10)

# %% [markdown]
# ## Cc72_00034723-RA和Cc72_00034924-RA是CA（辣椒素合成的同源基因），在56800 中分别排名第4、第5。结果符合预期

# %% [markdown]
# *************************

# %% [markdown]
# # 4.结果可视化

# %%
data = cat.merge_dataframes([granger, fc, pearson, spearman, gene])
data

# %%
# FC vs Granger
cat.plot_hexbin(data, 'log2FoldChange', 'Granger', gridsize=20)

# %%
# Fc vs Pearson
cat.plot_hexbin(data, 'log2FoldChange', 'Pearson', gridsize=20)

# %%
# Fc vs Spearman
cat.plot_hexbin(data, 'log2FoldChange', 'Spearman', gridsize=20)

# %% [markdown]
# *********************

# %%
#对log2FoldChange进行归一化，使得取值范围映射到 0-1
data = cat.scale_column(data, 'log2FoldChange')
data = cat.scale_column(data, 'Pearson')
data = cat.scale_column(data, 'Spearman')
data = data.fillna(0)

# %%
cat.plot_line_heatmap(data, 'Cc72_00034723-RA', cmap='vlag')

# %% [markdown]
# ### 对CA同源基因Cc72_00034723-RA进行可视化，其具有较高的Granger，FC，但Pearson和Spearman并不高

# %%
plot_for_hits = cat.merge_dataframes([data,gene])
plot_for_hits = plot_for_hits.drop(columns=['Description', 'score'])
plot_for_hits = plot_for_hits.head(10)
cat.plot_all_data(plot_for_hits)

# %% [markdown]
# ### 排名靠前的基因具有相似的时间序列

# %% [markdown]
# ****************

# %% [markdown]
# # 5.机制解释 (ChatGPT API)

# %%
cat.smart_aleck('What is the relationship between Acyltransferase Pun1 and capsaicin')

# %%
cat.smart_aleck('What is the relationship between Myricetin 3-O-methyltransferase 3 and capsaicin')

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

# %%
df_RNA = gene
df_metabolites = metabo
# Assuming df_RNA and df_metabolites are your dataframes

# Combine the dataframes for correlation
df = pd.concat([df_RNA, df_metabolites], axis=0)

# %%
# Calculate correlation matrix
corr, _ = spearmanr(df)

# %%
mask = np.abs(corr) > 0.7

# Create a graph
graph = nx.Graph()

# %%
# Add nodes
for i in range(df.shape[0]):
    graph.add_node(df.index[i])

# %%
# Add edges for significant correlations
for i in range(mask.shape[0]):
    for j in range(i+1, mask.shape[1]):
        if mask[i, j]:
            graph.add_edge(df.index[i], df.index[j], weight=corr[i, j])

# %%
# # Draw the graph
# nx.draw(graph, with_labels=True)
# plt.show()

# %%
top_nodes = 10

# Calculate degree for each node and sort
degree_sequence = sorted([(d, n) for n, d in graph.degree()], reverse=True)

# Get the top nodes
top_degree_nodes = [node[1] for node in degree_sequence[:top_nodes]]

# Get the neighbors of the top nodes
top_neighbors = {n: list(graph.neighbors(n)) for n in top_degree_nodes}

# Flatten the list of top nodes and their neighbors
nodes_subgraph = [node for sublist in top_neighbors.values() for node in sublist]
nodes_subgraph.extend(top_degree_nodes)

# Create a subgraph with the top nodes and their neighbors
subgraph = graph.subgraph(nodes_subgraph)

# Define node sizes and colors based on degree
# degree_subgraph = dict(subgraph.degree())
# node_sizes = [degree_subgraph[node] * 100 for node in subgraph.nodes()]
# node_colors = [degree_subgraph[node] for node in subgraph.nodes()]

# Draw the subgraph
nx.draw(subgraph, node_size=node_sizes, with_labels=True, font_size=8, font_color='tomato', node_color='navy', edge_color='gray')
plt.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# assuming `gene` is your DataFrame
# transpose your DataFrame, as PCA works on the features (columns), not on the samples (rows)
gene_transposed = gene.T

# Perform PCA on your data
pca = PCA(n_components=2)  # here we ask for the first two principal components
pca_result = pca.fit_transform(gene_transposed)

# convert the PCA result to a DataFrame
pca_df = pd.DataFrame(data = pca_result, columns = ['PC1', 'PC2'])

# add a 'sample' column
pca_df['sample'] = gene_transposed.index

# plot the result
plt.figure(figsize=(8,6))
sns.scatterplot(x="PC1", y="PC2", data=pca_df)

# annotate points on the graph with the sample names
for i, sample in enumerate(pca_df['sample']):
    plt.annotate(sample, (pca_df.iloc[i].PC1, pca_df.iloc[i].PC2))

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA on gene expression data')

plt.show()
